# %% [markdown]
# ## MLFlow avec Pyspark
#
# Avant de commencer, installez Spark en local en suivant le guide "Spark Installation.pdf"
#
# Nous allons suivre la même démarche que nous avons utilisé dans le premier notebook.
#
# Nous allons utilisé aussi le même dataset

# %%
import pyspark #
from pyspark.sql import SparkSession
from pyspark import SparkConf, SparkContext
from pyspark.sql.types import *
from pyspark.ml.feature import VectorAssembler
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
import pyspark.sql.functions as F
import os
import seaborn as sns
import sklearn #
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, accuracy_score
import matplotlib #
import matplotlib.pyplot as plt
import mlflow
import mlflow.spark
os.environ["SPARK_LOCAL_IP"]='127.0.0.1'
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.sparkContext._conf.getAll()
print("pyspark: {}".format(pyspark.__version__))
print("matplotlib: {}".format(matplotlib.__version__))
print("seaborn: {}".format(sns.__version__))
print("sklearn: {}".format(sklearn.__version__))
print("mlflow: {}".format(mlflow.__version__))
# Out:
# pyspark: 3.4.0
# matplotlib: 3.5.2
# seaborn: 0.11.2
# sklearn: 1.3.2
# mlflow: 2.9.2

# %%
# !pip install mlflow
# Out:
# Collecting mlflow
#   Using cached mlflow-2.9.2-py3-none-any.whl (19.1 MB)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (1.12.0)
# Requirement already satisfied: querystring-parser<2 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: waitress<3 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (2.1.2)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (6.0)
# Requirement already satisfied: packaging<24 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (21.3)
# Requirement already satisfied: Flask<4 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (2.1.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (0.4.4)
# Requirement already satisfied: pytz<2024 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (2022.7)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (3.3.4)
# Requirement already satisfied: docker<7,>=4.0.0 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (6.1.3)
# Requirement already satisfied: matplotlib<4 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (3.5.2)
# Requirement already satisfied: gitpython<4,>=2.1.0 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (3.1.37)
# Requirement already satisfied: scipy<2 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (1.9.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (2.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (1.3.2)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (4.23.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (4.11.3)
# Requirement already satisfied: pandas<3 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (1.4.4)
# Requirement already satisfied: entrypoints<1 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (0.4)
# Requirement already satisfied: pyarrow<15,>=4.0.0 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (9.0.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (1.4.39)
# Requirement already satisfied: click<9,>=7.0 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (8.0.4)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (0.18.0)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (2.28.1)
# Requirement already satisfied: numpy<2 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (1.23.5)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\oum\anaconda3\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: typing-extensions>=4 in c:\users\oum\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.3.0)
# Requirement already satisfied: Mako in c:\users\oum\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.2.4)
# Requirement already satisfied: colorama in c:\users\oum\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.6)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\oum\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.8.10)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\oum\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.4.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\oum\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in c:\users\oum\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.26.11)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\oum\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (3.2.2)
# Requirement already satisfied: pywin32>=304 in c:\users\oum\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow) (306)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\oum\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow) (0.58.0)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\oum\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\oum\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\oum\anaconda3\lib\site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\oum\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\oum\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\oum\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\oum\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\oum\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\oum\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\oum\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\oum\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\oum\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\oum\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\oum\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2022.9.14)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\oum\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\oum\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\oum\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (1.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\oum\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.1)
# Installing collected packages: mlflow
# WARNING: Ignoring invalid distribution -lflow (c:\users\oum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\oum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lflow (c:\users\oum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\oum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lflow (c:\users\oum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\oum\anaconda3\lib\site-packages)
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Oum\\anaconda3\\Scripts\\mlflow.exe' -> 'C:\\Users\\Oum\\anaconda3\\Scripts\\mlflow.exe.deleteme'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -lflow (c:\users\oum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\oum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lflow (c:\users\oum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\oum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lflow (c:\users\oum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\oum\anaconda3\lib\site-packages)

# %%
data_path = 'data/creditcard.csv'
df = spark.read.csv(data_path, header = True,
inferSchema = True)
labelColumn = "Class"
columns = df.columns
numericCols = columns
numericCols.remove("Time")
numericCols.remove(labelColumn)
print(numericCols)
# Out:
# ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']

# %%
df.toPandas().head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
stages = []
assemblerInputs = numericCols
assembler = VectorAssembler(inputCols=assemblerInputs,
outputCol="features")
stages += [assembler]
dfFeatures = df.select(F.col(labelColumn).alias('label'),*numericCols )
normal = dfFeatures.filter("Class == 0").sample(withReplacement=False, fraction=0.5, seed=2020)
anomaly = dfFeatures.filter("Class == 1")
normal_train, normal_test = normal.randomSplit([0.8, 0.2],seed = 2020)
anomaly_train, anomaly_test = anomaly.randomSplit([0.8, 0.2],seed = 2020)

# %%
dfFeatures.toPandas().head()
# Out:
#    label        V1        V2        V3        V4        V5        V6  \
# 0      0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1      0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2      0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3      0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4      0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V20       V21       V22       V23  \
# 0  0.239599  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474
# 1 -0.078803  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.791461  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.237609  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321
# 4  0.592941 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 30 columns]

# %%
train_set = normal_train.union(anomaly_train)
test_set = normal_test.union(anomaly_test)

# %%
pipeline = Pipeline(stages = stages)
pipelineModel = pipeline.fit(dfFeatures)
train_set = pipelineModel.transform(train_set)
test_set = pipelineModel.transform(test_set)
selectedCols = ['label', 'features'] + numericCols
train_set = train_set.select(selectedCols)
test_set = test_set.select(selectedCols)
print("Training Dataset Count: ", train_set.count())
print("Test Dataset Count: ", test_set.count())
# Out:
# Training Dataset Count:  114389
# Test Dataset Count:  28459

# %%
def train(spark_model, train_set):
    trained_model = spark_model.fit(train_set)
    trainingSummary = trained_model.summary
    pyspark_auc_score = trainingSummary.areaUnderROC
    mlflow.log_metric("train_acc", trainingSummary.accuracy)
    mlflow.log_metric("train_AUC", pyspark_auc_score)
    mlflow.log_
    print("Training Accuracy: ", trainingSummary.accuracy)
    print("Training AUC:", pyspark_auc_score)
    return trained_model

# %%
def evaluate(spark_model, test_set):
    evaluation_summary = spark_model.evaluate(test_set)
    eval_acc = evaluation_summary.accuracy
    eval_AUC = evaluation_summary.areaUnderROC
    mlflow.log_metric("eval_acc", eval_acc)
    mlflow.log_metric("eval_AUC", eval_AUC)
    print("Evaluation Accuracy: ", eval_acc)
    print("Evaluation AUC: ", eval_AUC)

# %%
lr = LogisticRegression(featuresCol = 'features', labelCol ='label', maxIter=10)
mlflow.set_experiment("PySpark_CreditCard")
with mlflow.start_run():
    trainedLR = train(lr, train_set)
    evaluate(trainedLR, test_set)
    mlflow.spark.log_model(trainedLR,"creditcard_model_pyspark")
mlflow.end_run()
# Out:
# 2024/01/07 23:15:07 INFO mlflow.tracking.fluent: Experiment with name 'PySpark_CreditCard' does not exist. Creating a new experiment.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16780\3480034516.py in <module>
#       2 mlflow.set_experiment("PySpark_CreditCard")
#       3 with mlflow.start_run():
# ----> 4     trainedLR = train(lr, train_set)
#       5     evaluate(trainedLR, test_set)
#       6     mlflow.spark.log_model(trainedLR,"creditcard_model_pyspark")
#
# ~\AppData\Local\Temp\ipykernel_16780\925955119.py in train(spark_model, train_set)
#       5     mlflow.log_metric("train_acc", trainingSummary.accuracy)
#       6     mlflow.log_metric("train_AUC", pyspark_auc_score)
# ----> 7     mlflow.log_
#       8     print("Training Accuracy: ", trainingSummary.accuracy)
#       9     print("Training AUC:", pyspark_auc_score)
#
# AttributeError: module 'mlflow' has no attribute 'log_'

# %% [markdown]
# ## Loading the model
#
# copiez l'ID run a partir de l'interface MLFlow

# %%
model = mlflow.spark.load_model("runs:/votre_RUN_ID/creditcard_model_pyspark")

# %%
predictions = model.transform(test_set)
y_true = predictions.select(['label']).collect()
y_pred = predictions.select(['prediction']).collect()

# %%
print(f"AUC Score: {roc_auc_score(y_true, y_pred):.3%}")
print(f"Accuracy Score: {accuracy_score(y_true, y_pred):.3%}")

# %%
conf_matrix = confusion_matrix(y_true, y_pred)
ax = sns.heatmap(conf_matrix, annot=True,fmt='g')
ax.invert_xaxis()
ax.invert_yaxis()
plt.ylabel('Actual')
plt.xlabel('Predicted')
